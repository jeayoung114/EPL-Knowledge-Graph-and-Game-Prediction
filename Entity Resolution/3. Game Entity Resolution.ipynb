# %%
# !pip install strsimpy
from strsimpy.jaro_winkler import JaroWinkler
from strsimpy.normalized_levenshtein import NormalizedLevenshtein

import pandas as pd
import numpy as np
import json
import fileinput
from tqdm import tqdm
import string
import re
import json
from os import walk
import os
import ast
import re

data_dir = "../data/structured_data/"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: strsimpy in /Users/jaeyoungkim/.local/lib/python3.7/site-packages (0.2.1)
# WARNING: You are using pip version 21.1.2; however, version 21.3.1 is available.
# You should consider upgrading via the '/opt/anaconda3/envs/jaeyoung/bin/python -m pip install --upgrade pip' command.

# %%
f = []
for (dirpath, dirnames, filenames) in walk(data_dir):
    f.extend(filenames)

# %%
tot_game_df = pd.DataFrame()
for file in f:
    if file[0] == "s":
        df = pd.read_csv(data_dir + file)
        tot_game_df = tot_game_df.append(df)

# %%
def f(x):
    if "/" in x:
        tmp = x.split("/")
        tmp = tmp[2] + "-" + tmp[1] + "-" + tmp[0]
        if len(tmp) == 8:
            return "20" + tmp
        return tmp
    elif len(x) == 8:
        return '20' + x
    else:
        return x
tot_game_df["date"] = tot_game_df["Date"].apply(lambda x : f(x))

# %%
data_dir = "../"

# %%
world_game = pd.DataFrame()
with fileinput.input(files=data_dir + "worldfootball_crawler/game_worldfootball.jl") as file:
    for line in file:
        conv = json.loads(line)
        world_game = world_game.append(conv, ignore_index=True)
world_game.head()
# Out:
#       season round        data   time         home_team  \
# 0  2009/2010     7  26/09/2009  15:00   Birmingham City
# 1  2009/2010     7  26/09/2009  12:45     Portsmouth FC
# 2  2009/2010     5  12/09/2009  15:00  Blackburn Rovers
# 3  2009/2010     4  29/08/2009  12:45        Chelsea FC
# 4  2009/2010     5  12/09/2009  15:00      Liverpool FC
#
#                  away_team score  \
# 0         Bolton Wanderers   1:2
# 1               Everton FC   0:1
# 2  Wolverhampton Wanderers   3:1
# 3               Burnley FC   3:0
# 4               Burnley FC   4:0
#
#                                        home_team_url  \
# 0  https://www.worldfootball.net/teams/birmingham...
# 1  https://www.worldfootball.net/teams/portsmouth...
# 2  https://www.worldfootball.net/teams/blackburn-...
# 3    https://www.worldfootball.net/teams/chelsea-fc/
# 4  https://www.worldfootball.net/teams/liverpool-fc/
#
#                                        away_team_url  \
# 0  https://www.worldfootball.net/teams/bolton-wan...
# 1    https://www.worldfootball.net/teams/everton-fc/
# 2  https://www.worldfootball.net/teams/wolverhamp...
# 3    https://www.worldfootball.net/teams/burnley-fc/
# 4    https://www.worldfootball.net/teams/burnley-fc/
#
#                                          goal_player  ...  \
# 0  [Tamir Cohen, Kevin Davies, Kevin Phillips, Ch...  ...
# 1                        [Louis Saha, John Heitinga]  ...
# 2  [El-Hadji Diouf, Jason Roberts, Gaël Givet, Da...  ...
# 3  [Nicolas Anelka, Didier Drogba, Michael Ballac...  ...
# 4  [Yossi Benayoun, Glen Johnson, Dirk Kuyt, Yoss...  ...
#
#                                home_team_manager_url away_team_manager  \
# 0  https://www.worldfootball.net/player_summary/a...       Gary Megson
# 1  https://www.worldfootball.net/player_summary/p...       David Moyes
# 2  https://www.worldfootball.net/player_summary/s...     Mick McCarthy
# 3  https://www.worldfootball.net/player_summary/c...        Owen Coyle
# 4  https://www.worldfootball.net/player_summary/r...        Owen Coyle
#
#                                away_team_manager_url             stadium  \
# 0  https://www.worldfootball.net/player_summary/g...  St Andrew's Ground
# 1  https://www.worldfootball.net/player_summary/d...        Fratton Park
# 2  https://www.worldfootball.net/player_summary/m...          Ewood Park
# 3  https://www.worldfootball.net/player_summary/o...     Stamford Bridge
# 4  https://www.worldfootball.net/player_summary/o...             Anfield
#
#         stadium_country                                        stadium_url  \
# 0  Birmingham / England  https://www.worldfootball.net/venues/st-andrew...
# 1  Portsmouth / England  https://www.worldfootball.net/venues/fratton-p...
# 2   Blackburn / England  https://www.worldfootball.net/venues/ewood-par...
# 3      London / England  https://www.worldfootball.net/venues/stamford-...
# 4   Liverpool / England  https://www.worldfootball.net/venues/anfield-l...
#
#         refree_name refree_country  \
# 0     Steve Bennett        England
# 1        Alan Wiley        England
# 2     Steve Bennett        England
# 3  Mark Clattenburg        England
# 4         Lee Mason        England
#
#                                           refree_url num_audience
# 0  https://www.worldfootball.net/referee_summary/...        28671
# 1  https://www.worldfootball.net/referee_summary/...        18116
# 2  https://www.worldfootball.net/referee_summary/...        24845
# 3  https://www.worldfootball.net/referee_summary/...        40906
# 4  https://www.worldfootball.net/referee_summary/...        43817
#
# [5 rows x 24 columns]

# %%
len(world_game)
# Out:
# 4444

# %%
who_game = pd.DataFrame()
with fileinput.input(files=data_dir + "whoscored_crawler/games_whoscored.jl") as file:
    for line in file:
        conv = json.loads(line)
        who_game = who_game.append(conv, ignore_index=True)
who_game.head()
# Out:
#                                             game_url     season  \
# 0  https://www.whoscored.com/Matches/959577/Live/...  2015/2016
# 1  https://www.whoscored.com/Matches/411043/Live/...  2010/2011
# 2  https://www.whoscored.com/Matches/411264/Live/...  2010/2011
# 3  https://www.whoscored.com/Matches/1285010/Live...  2018/2019
# 4  https://www.whoscored.com/Matches/411389/Live/...  2010/2011
#
#   home_team_formation home_team_rating  home_team  \
# 0             4-4-1-1             6.86  West Brom
# 1               4-4-2             7.08      Stoke
# 2               4-4-2             6.72  Blackpool
# 3             4-1-4-1             7.54  Leicester
# 4               4-4-2             7.03    Man Utd
#
#                                        home_team_url away_team_formation  \
# 0  https://www.whoscored.com/Teams/175/Show/Engla...               4-3-3
# 1  https://www.whoscored.com/Teams/96/Show/Englan...               4-5-1
# 2  https://www.whoscored.com/Teams/93/Show/Englan...               4-4-2
# 3  https://www.whoscored.com/Teams/14/Show/Englan...               4-4-2
# 4  https://www.whoscored.com/Teams/32/Show/Englan...               4-5-1
#
#   away_team_rating    away_team  \
# 0             6.97  Aston Villa
# 1             6.74  Aston Villa
# 2             7.13   Birmingham
# 3             6.26      Arsenal
# 4             6.60      Everton
#
#                                        away_team_url  \
# 0  https://www.whoscored.com/Teams/24/Show/Englan...
# 1  https://www.whoscored.com/Teams/24/Show/Englan...
# 2  https://www.whoscored.com/Teams/157/Show/Engla...
# 3  https://www.whoscored.com/Teams/13/Show/Englan...
# 4  https://www.whoscored.com/Teams/31/Show/Englan...
#
#                                        player_rating   time            date
# 0  {'11530': {'rating': '7.3', 'shirt_number': '1...  15:00  Sat, 23-Jan-16
# 1  {'3184': {'rating': '7.5', 'shirt_number': '29...  20:00  Mon, 13-Sep-10
# 2  {'21050': {'rating': '6.7', 'shirt_number': '2...  20:00  Tue, 04-Jan-11
# 3  {'19545': {'rating': '7.3', 'shirt_number': '1...  12:00  Sun, 28-Apr-19
# 4  {'3101': {'rating': '7.1', 'shirt_number': '1....  12:45  Sat, 23-Apr-11

# %%
month_dict = {"Jan" : "01", "Feb" : "02", "Mar" : "03", "Apr" : "04", "May" : "05", "Jun" : "06", "Jul" : "07", "Aug" : "08", "Sep" : "09", "Oct" : "10", "Nov" : "11", "Dec" : 12}

# %%
who_game["date"] = who_game["date"].apply(lambda x : x.split(",")[1].split("-")).apply(lambda x : "20" + str(x[2]) + "-" + str(month_dict[x[1]]) + "-" + str(x[0]).strip())

# %%
world_game["date"] = world_game["data"].apply(lambda x : x.split("/"))
world_game["date"] = world_game["date"].apply(lambda x : x[2] + "-" + x[1] + "-" + x[0])

# %%
## get team match
team_match = pd.read_csv("../data/" + "team_match.csv", index_col = 'id')

# %%
world_game["home_team_id"] = world_game['home_team_url'].apply(lambda x : team_match[team_match["world_team_url"] == x].index[0])

world_game["away_team_id"] = world_game['away_team_url'].apply(lambda x : team_match[team_match["world_team_url"] == x].index[0])

# %%
def f(x):
    tmp = x
    if x == 'https://www.whoscored.com/Teams/175/Show/England-West-Brom':
        tmp = 'https://www.whoscored.com/Teams/175/Show/England-West-Bromwich-Albion'

    def g(x):
        if type(x)== float:
            return None
        else:
            return x.split("/")[4]
    
    return team_match[team_match["who_team_url"].apply(lambda x : g(x)) == tmp.split("/")[4]].index[0]
who_game["home_team_id"] = who_game['home_team_url'].apply(lambda x : f(x))
who_game["away_team_id"] = who_game['away_team_url'].apply(lambda x : f(x))

# %%
team_match["team_name"] = team_match["wiki_team_url"].apply(lambda x : x.split("/")[-1])

# %%
wiki_name2idx = dict()
wiki_idx2name = dict()
for idx, row in team_match.iterrows():
    wiki_name2idx[row.team_name] = idx
    wiki_idx2name[idx] = row.team_name

# %%
Lev = NormalizedLevenshtein().similarity

# %%
def f(x):
    tmp = [0,0]
    for name in team_match["team_name"]:
        if Lev(x, name) > 0.3 and Lev(x, name) > tmp[1]:
            tmp[0] = wiki_name2idx[name]
            tmp[1] = Lev(x,name)
    if x == "Wolves":
        return 3
    if x == "QPR":
        return 24
    if x == 'Man City':
        return 7
    if tmp != [0,0]:
        return int(tmp[0])

tot_game_df["home_team_id"] = tot_game_df["HomeTeam"].apply(f)
tot_game_df["away_team_id"] = tot_game_df["AwayTeam"].apply(f)

# %%
world_who_game = world_game.merge(who_game, left_on = ["home_team_id", "away_team_id", "date"], right_on = ["home_team_id", "away_team_id", "date"], how = "outer", suffixes = ["_world", "_who"])

# %%
all_merged = world_who_game.merge(tot_game_df, left_on = ["home_team_id", "away_team_id", "date"], right_on = ["home_team_id", "away_team_id", "date"], how = "outer", suffixes = ["_world_who", "_structured"])

# %%
all_merged
# Out:
#      season_world round        data time_world   home_team_world  \
# 0       2009/2010     7  26/09/2009      15:00   Birmingham City
# 1       2009/2010     7  26/09/2009      12:45     Portsmouth FC
# 2       2009/2010     5  12/09/2009      15:00  Blackburn Rovers
# 3       2009/2010     4  29/08/2009      12:45        Chelsea FC
# 4       2009/2010     5  12/09/2009      15:00      Liverpool FC
# ...           ...   ...         ...        ...               ...
# 4833          NaN   NaN         NaN        NaN               NaN
# 4834          NaN   NaN         NaN        NaN               NaN
# 4835          NaN   NaN         NaN        NaN               NaN
# 4836          NaN   NaN         NaN        NaN               NaN
# 4837          NaN   NaN         NaN        NaN               NaN
#
#               away_team_world score  \
# 0            Bolton Wanderers   1:2
# 1                  Everton FC   0:1
# 2     Wolverhampton Wanderers   3:1
# 3                  Burnley FC   3:0
# 4                  Burnley FC   4:0
# ...                       ...   ...
# 4833                      NaN   NaN
# 4834                      NaN   NaN
# 4835                      NaN   NaN
# 4836                      NaN   NaN
# 4837                      NaN   NaN
#
#                                     home_team_url_world  \
# 0     https://www.worldfootball.net/teams/birmingham...
# 1     https://www.worldfootball.net/teams/portsmouth...
# 2     https://www.worldfootball.net/teams/blackburn-...
# 3       https://www.worldfootball.net/teams/chelsea-fc/
# 4     https://www.worldfootball.net/teams/liverpool-fc/
# ...                                                 ...
# 4833                                                NaN
# 4834                                                NaN
# 4835                                                NaN
# 4836                                                NaN
# 4837                                                NaN
#
#                                     away_team_url_world  \
# 0     https://www.worldfootball.net/teams/bolton-wan...
# 1       https://www.worldfootball.net/teams/everton-fc/
# 2     https://www.worldfootball.net/teams/wolverhamp...
# 3       https://www.worldfootball.net/teams/burnley-fc/
# 4       https://www.worldfootball.net/teams/burnley-fc/
# ...                                                 ...
# 4833                                                NaN
# 4834                                                NaN
# 4835                                                NaN
# 4836                                                NaN
# 4837                                                NaN
#
#                                             goal_player  ...    LBA   SJH  \
# 0     [Tamir Cohen, Kevin Davies, Kevin Phillips, Ch...  ...   3.25  2.20
# 1                           [Louis Saha, John Heitinga]  ...   1.83  4.00
# 2     [El-Hadji Diouf, Jason Roberts, Gaël Givet, Da...  ...   4.50  1.80
# 3     [Nicolas Anelka, Didier Drogba, Michael Ballac...  ...  12.00  1.14
# 4     [Yossi Benayoun, Glen Johnson, Dirk Kuyt, Yoss...  ...  15.00  1.18
# ...                                                 ...  ...    ...   ...
# 4833                                                NaN  ...   3.10   NaN
# 4834                                                NaN  ...   3.10  2.50
# 4835                                                NaN  ...   2.10  3.60
# 4836                                                NaN  ...   3.75  2.05
# 4837                                                NaN  ...   7.50  1.50
#
#        SJD    SJA   BSH   BSD    BSA   SBH   SBD    SBA
# 0     3.25   3.30  2.20  3.10   3.40  2.20  3.20   3.00
# 1     3.30   1.95  3.90  3.40   1.95  3.60  3.30   1.91
# 2     3.50   4.50  1.83  3.30   4.75  1.80  3.25   4.20
# 3     7.50  19.00  1.12  7.00  21.00  1.12  7.00  15.00
# 4     6.50  15.00  1.20  6.00  17.00  1.13  6.60  15.00
# ...    ...    ...   ...   ...    ...   ...   ...    ...
# 4833   NaN    NaN   NaN   NaN    NaN   NaN   NaN    NaN
# 4834  3.25   2.88   NaN   NaN    NaN   NaN   NaN    NaN
# 4835  3.40   2.05   NaN   NaN    NaN   NaN   NaN    NaN
# 4836  3.40   3.60  2.00  3.40   3.60  2.00  3.25   3.40
# 4837  3.90   7.50  1.50  3.75   7.00  1.40  4.00   7.50
#
# [4838 rows x 116 columns]

# %%
all_merged.to_csv("../data/" + "game_join.csv", index = None)
