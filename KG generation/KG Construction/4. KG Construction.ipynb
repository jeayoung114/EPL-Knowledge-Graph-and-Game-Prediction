# %%
# !pip install strsimpy
from strsimpy.jaro_winkler import JaroWinkler
from strsimpy.normalized_levenshtein import NormalizedLevenshtein

import pandas as pd
import numpy as np
import openpyxl
import json
import re
import ast
from collections import Counter
from rdflib import Graph, URIRef, Literal, XSD, Namespace, RDF, BNode, RDFS

import rdflib
from rdflib import Literal, RDF, URIRef, Namespace
from rdflib.namespace import RDFS,RDF,XSD
from tqdm import tqdm
import dateparser
import dateutil.parser as date_parse
data_dir = "../data_/"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: strsimpy in /Users/jaeyoungkim/.local/lib/python3.7/site-packages (0.2.1)
# WARNING: You are using pip version 21.1.2; however, version 21.3.1 is available.
# You should consider upgrading via the '/opt/anaconda3/envs/jaeyoung/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# ## 1.  Player

# %%
player_df  = pd.read_csv(data_dir + "player_join.csv", index_col = 0)
player_df.head()
# Out:
#                                         team_history  \
# 0  {'0': {'period': '07/2011 - 06/2012', 'team': ...
# 1  {'0': {'period': '10/2017 - 06/2019', 'team': ...
# 2  {'1': {'period': '07/2020 - 08/2020', 'team': ...
# 3  {'1': {'period': '07/2016 - 06/2019', 'team': ...
# 4  {'0': {'period': '07/2013 - 06/2016', 'team': ...
#
#                                         player_url_x             name  \
# 0  https://www.worldfootball.net/player_summary/m...  Michael Johnson
# 1  https://www.worldfootball.net/player_summary/r...    Roger Johnson
# 2  https://www.worldfootball.net/player_summary/j...      Jake Jervis
# 3  https://www.worldfootball.net/player_summary/j...     Jake Bidwell
# 4  https://www.worldfootball.net/player_summary/b...         Bosingwa
#
#              Born                  Placeofbirth            Nationality_x  \
# 0  ['24.02.1988']        ['Urmston', 'England']              ['England']
# 1  ['28.04.1983']        ['Ashford', 'England']              ['England']
# 2  ['17.09.1991']  ['Wolverhampton', 'England']              ['England']
# 3  ['21.03.1993']      ['Southport', 'England']              ['England']
# 4  ['24.08.1982']       ['Mbandaka', 'CongoDR']  ['Portugal', 'CongoDR']
#
#     Height_x    Weight                       Position(s)       Foot  ...  \
# 0  ['183cm']  ['79kg']           ['DefensiveMidfielder']  ['right']  ...
# 1  ['191cm']  ['78kg']                    ['CentreBack']  ['right']  ...
# 2  ['191cm']       NaN  ['RightWinger', 'CentreForward']  ['right']  ...
# 3  ['183cm']  ['80kg']    ['LeftBack', 'LeftMidfielder']   ['left']  ...
# 4  ['183cm']  ['75kg']  ['RightBack', 'RightMidfielder']  ['right']  ...
#
#   Height_y Nationality_y          Positions              Strengths  \
# 0    183cm       England         Midfielder                    NaN
# 1    191cm       England  Defender (Centre)  ['Blocking the ball']
# 2      NaN           NaN                NaN                    NaN
# 3      NaN           NaN                NaN                    NaN
# 4      NaN           NaN                NaN                    NaN
#
#     Weaknesses                                      Style_of_Play  \
# 0          NaN                                                NaN
# 1  ['Passing']  ['Indirect set-piece threat', 'Likes to play l...
# 2          NaN                                                NaN
# 3          NaN                                                NaN
# 4          NaN                                                NaN
#
#   Current Team         DOB  birth_block_y  player_id_y
# 0          NaN  24-02-1988     19880224.0    2000534.0
# 1          NaN  28-04-1983     19830428.0    2000086.0
# 2          NaN         NaN            NaN          NaN
# 3          NaN         NaN            NaN          NaN
# 4          NaN         NaN            NaN          NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Data preprocessing

# %%
## Position(s)
def f(x):
    if type(x) == float:
        return x
    else:
        x = ast.literal_eval(x)
        res = [" ".join([s for s in re.split("([A-Z][^A-Z]*)", i) if s]) for i in x]
        return res
    
player_df["Position(s)"] = player_df["Position(s)"].apply(f)

# %%
## Positions
def f(x):
    if type(x) == float:
        return x
    tmp = x.split('(')
    if len(tmp) == 1:
        return tmp
    if len(tmp) == 2:
        res = []
        sub = tmp[1]
        sub = re.sub("\(", "" , sub)
        sub = re.sub("\)", "" , sub)
        sub = re.sub(",,",",",sub)
        sub = sub.split(",")
        res = [i +" "+ tmp[0] for i in sub]
        res = [i.strip() for i in res]
        return res
    
def g(x):
    if type(x) == float:
        return x
    elif x[0] == 'C Defensive Midfielder':
        x[0] = 'Centre Defensive Midfielder'
    return x
    
    
player_df["Positions"] = player_df["Positions"].apply(f).apply(g)

# %% [markdown]
# ## KG

# %%
QB = Namespace('http://purl.org/linked-data/cube#')
MYNS = Namespace('http://dsci558.org/myprojectnamespace#')
RDFS = Namespace("http://www.w3.org/2000/01/rdf-schema#")
SCHEMA = Namespace("https://schema.org/")
WIKIDATA = Namespace("https://wikidata.org/")

# %%
my_kg = rdflib.Graph()
my_kg.bind('qb',QB)
my_kg.bind('my_ns', MYNS)
my_kg.bind('rdfs',RDFS)
my_kg.bind("schema", SCHEMA)
my_kg.bind('rdfs',RDFS)
my_kg.bind('wiki', WIKIDATA)

# %%
x = [ast.literal_eval(i) for i in list(player_df["Nationality_x"].dropna())]
flatten_list = [j for sub in x for j in sub]

# %%
country_list_y = list(set(player_df["Nationality_y"].dropna()))

# %%
## Country Entities
x = [ast.literal_eval(i) for i in list(player_df["Nationality_x"].dropna())]
flatten_list = [j for sub in x for j in sub]
country_list = set(flatten_list + country_list_y)

for country in country_list:
    revised_name = re.sub("[^a-zA-Z]", "_", country)
    country_uri = URIRef(MYNS[revised_name])
    my_kg.add((country_uri, RDF.type, SCHEMA.Country))
    my_kg.add((country_uri, RDFS.label, Literal(country)))

# %%
city_list = set(player_df["Placeofbirth"].dropna().apply(lambda x : ast.literal_eval(x)[0]))

# %%
## City Entities
for city in city_list:
    revised_name = re.sub("[^a-zA-Z]", "_", city)
    city_uri = URIRef(MYNS[revised_name])
    my_kg.add((city_uri, RDF.type, MYNS['city']))
    my_kg.add((city_uri, RDF.type, SCHEMA.Place))
    my_kg.add((city_uri, RDFS.label, Literal(city)))

# %%
tmp = []
for i in list(player_df["Positions"].dropna()):
    tmp += i
for i in list(player_df["Position(s)"].dropna()):
    tmp += i
position_list = set(tmp)

# %%
## Position Entities
for position in position_list:
    revised_name = re.sub("[^a-zA-Z]", "_", position)
    position_uri = URIRef(MYNS[revised_name])
    my_kg.add((position_uri, RDF.type, MYNS['position']))
    my_kg.add((position_uri, RDFS.label, Literal(position)))

# %%
## Team Entities

# %%
player_df = player_df.fillna("nan")

# %%
def f(x):
    if x.player_id_x != 'nan':
        tmp1 = str(int(x.player_id_x))
    else:
        tmp1 = "nan"
    if x.player_id_y != 'nan':
        tmp2 = str(int(x.player_id_y))
    else:
        tmp2 = "nan"
    return tmp1 + "_" + tmp2
player_df["player_id_tot"] = player_df.apply(f, axis = 1 )

# %%
player_df["team_history"][0]
# Out:
# "{'0': {'period': '07/2011 - 06/2012', 'team': 'Leicester City', 'position': 'Midfielder', 'team_url': 'https://www.worldfootball.net/teams/leicester-city/'}, '1': {'period': '07/2006 - 07/2011', 'team': 'Manchester City', 'position': 'Midfielder', 'team_url': 'https://www.worldfootball.net/teams/manchester-city/'}}"

# %%
json_list = []
for js in list(player_df[player_df["team_history"]!='nan']["team_history"]):
    js = re.sub("L'A", "LA", js)
    js = re.sub("l'A", "lA", js)
    js = re.sub("O'H", "OH", js)
    js = re.sub("e'e", "ee", js)
    js = re.sub("d'A", "dA", js)
    js = re.sub("a'a", "aa", js)
    js = re.sub("L'H", "LH", js)
    js = re.sub("d'Á", "dÁ", js)
    js = re.sub("'s ", "s ", js)
    
    js = re.sub("'", "\"", js)
    json_list.append(json.loads(js))

# %%
json_list[0]
# Out:
# {'0': {'period': '07/2011 - 06/2012',
#   'team': 'Leicester City',
#   'position': 'Midfielder',
#   'team_url': 'https://www.worldfootball.net/teams/leicester-city/'},
#  '1': {'period': '07/2006 - 07/2011',
#   'team': 'Manchester City',
#   'position': 'Midfielder',
#   'team_url': 'https://www.worldfootball.net/teams/manchester-city/'}}

# %%
team_list = []
for js in json_list:
    jss = js.values()
    for i in jss:
        team = i["team"]
        team_url = i["team_url"]
        if team != "":
            team_list.append((team, team_url))

# %%
for team in set(team_list):
    revised_name = re.sub("[^a-zA-Z]", "_", team[0])
    team_uri = URIRef(MYNS[revised_name])
    my_kg.add((team_uri, RDF.type, SCHEMA.SportsTeam))
    my_kg.add((team_uri, RDFS.label, Literal(team[0])))
    my_kg.add((team_uri, MYNS["worldfootball_url"], Literal(team[1])))

# %%
json.loads(re.sub("'", "\"", player_df["team_history"].dropna()[9]))
# Out:
# {'0': {'period': '01/2018 - 12/2019',
#   'team': 'Balmazújvárosi FC',
#   'position': 'Forward',
#   'team_url': 'https://www.worldfootball.net/teams/balmazujvarosi-fc/'},
#  '1': {'period': '02/2016 - 06/2017',
#   'team': 'Nyíregyháza Spartacus',
#   'position': 'Forward',
#   'team_url': 'https://www.worldfootball.net/teams/nyiregyhaza-spartacus/'},
#  '2': {'period': '07/2015 - 02/2016',
#   'team': 'Mezőkövesdi SE',
#   'position': 'Forward',
#   'team_url': 'https://www.worldfootball.net/teams/mezoekoevesdi-se/'},
#  '3': {'period': '07/2014 - 06/2015',
#   'team': 'Puskás FC',
#   'position': 'Forward',
#   'team_url': 'https://www.worldfootball.net/teams/puskas-fc/'},
#  '4': {'period': '08/2013 - 06/2014',
#   'team': 'Mezőkövesdi SE',
#   'position': 'Forward',
#   'team_url': 'https://www.worldfootball.net/teams/mezoekoevesdi-se/'},
#  '5': {'period': '09/2012 - 08/2013',
#   'team': 'Spartak Myjava',
#   'position': 'Forward',
#   'team_url': 'https://www.worldfootball.net/teams/spartak-myjava/'},
#  '6': {'period': '01/2012 - 08/2012',
#   'team': 'Pécsi MFC',
#   'position': 'Forward',
#   'team_url': 'https://www.worldfootball.net/teams/pecsi-mfc/'},
#  '7': {'period': '07/2011 - 12/2011',
#   'team': 'DAC Dunajská Streda',
#   'position': 'Forward',
#   'team_url': 'https://www.worldfootball.net/teams/dac-dunajska-streda/'},
#  '8': {'period': '01/2011 - 06/2011',
#   'team': 'Paykan FC',
#   'position': 'Forward',
#   'team_url': 'https://www.worldfootball.net/teams/paykan-fc/'},
#  '9': {'period': '07/2010 - 12/2010',
#   'team': 'DAC Dunajská Streda',
#   'position': 'Forward',
#   'team_url': 'https://www.worldfootball.net/teams/dac-dunajska-streda/'},
#  '10': {'period': '01/2007 - 06/2010',
#   'team': 'Bolton Wanderers',
#   'position': 'Forward',
#   'team_url': 'https://www.worldfootball.net/teams/bolton-wanderers/'},
#  '11': {'period': '07/2006 - 01/2007',
#   'team': 'FC Senec',
#   'position': 'Forward',
#   'team_url': 'https://www.worldfootball.net/teams/fc-senec/'}}

# %% [markdown]
# ## Predicate

# %%
predicate_uri = MYNS["position"]
my_kg.add((predicate_uri, RDF.type, RDF.Property))
my_kg.add((predicate_uri, RDFS.label, Literal("position", lang = 'en')))
# Out:
# <Graph identifier=Ndd76c1df1d4b44e4b54ec48544e9a70e (<class 'rdflib.graph.Graph'>)>

# %%
predicate_uri = MYNS["Foot"]
my_kg.add((predicate_uri, RDF.type, RDF.Property))
my_kg.add((predicate_uri, RDFS.label, Literal("Foot", lang = 'en')))
# Out:
# <Graph identifier=Ndd76c1df1d4b44e4b54ec48544e9a70e (<class 'rdflib.graph.Graph'>)>

# %%
predicate_uri = MYNS["shirtNumber"]
my_kg.add((predicate_uri, RDF.type, RDF.Property))
my_kg.add((predicate_uri, RDFS.label, Literal("shirtNumber", lang = 'en')))
# Out:
# <Graph identifier=Ndd76c1df1d4b44e4b54ec48544e9a70e (<class 'rdflib.graph.Graph'>)>

# %%
predicate_uri = MYNS["strength"]
my_kg.add((predicate_uri, RDF.type, RDF.Property))
my_kg.add((predicate_uri, RDFS.label, Literal("strength", lang = 'en')))
# Out:
# <Graph identifier=Ndd76c1df1d4b44e4b54ec48544e9a70e (<class 'rdflib.graph.Graph'>)>

# %%
predicate_uri = MYNS["weakness"]
my_kg.add((predicate_uri, RDF.type, RDF.Property))
my_kg.add((predicate_uri, RDFS.label, Literal("weakness", lang = 'en')))
# Out:
# <Graph identifier=Ndd76c1df1d4b44e4b54ec48544e9a70e (<class 'rdflib.graph.Graph'>)>

# %%
predicate_uri = MYNS["styleofPlay"]
my_kg.add((predicate_uri, RDF.type, RDF.Property))
my_kg.add((predicate_uri, RDFS.label, Literal("styleofPlay", lang = 'en')))
# Out:
# <Graph identifier=Ndd76c1df1d4b44e4b54ec48544e9a70e (<class 'rdflib.graph.Graph'>)>

# %%
predicate_uri = MYNS["worldfootball_url"]
my_kg.add((predicate_uri, RDF.type, RDF.Property))
my_kg.add((predicate_uri, RDFS.label, Literal("worldfootball_url", lang = 'en')))
# Out:
# <Graph identifier=Ndd76c1df1d4b44e4b54ec48544e9a70e (<class 'rdflib.graph.Graph'>)>

# %%
predicate_uri = MYNS["whoscored_url"]
my_kg.add((predicate_uri, RDF.type, RDF.Property))
my_kg.add((predicate_uri, RDFS.label, Literal("whoscored_url", lang = 'en')))
# Out:
# <Graph identifier=Ndd76c1df1d4b44e4b54ec48544e9a70e (<class 'rdflib.graph.Graph'>)>

# %%
predicate_uri = MYNS["Age"]
my_kg.add((predicate_uri, RDF.type, RDF.Property))
my_kg.add((predicate_uri, RDFS.label, Literal("Age", lang = 'en')))
# Out:
# <Graph identifier=Ndd76c1df1d4b44e4b54ec48544e9a70e (<class 'rdflib.graph.Graph'>)>

# %%
# predicate_uri = MYNS["url"]
# my_kg.add((predicate_uri, RDF.type, RDF.Property))
# my_kg.add((predicate_uri, RDFS.label, Literal("Age", lang = 'en')))

# %%
my_kg.serialize('data.ttl', format="turtle")
# Out:
# <Graph identifier=Ndd76c1df1d4b44e4b54ec48544e9a70e (<class 'rdflib.graph.Graph'>)>

# %%
# SCHEMA.name
# SCHEMA.brithPlace
# SCHEMA.birthDate
# SCHEMA.nationality
# SCHEMA.height    SCHEMA.QuantitativeValue
# SCHEMA.weight    SCHEMA.QuantitativeValue
# MYNS["position"]
# MYNS["footSize"] SCHEMA.QuantitativeValue
# MYNS["footSize"] a SCHEMA.size
# MYNS["shirtNumber"] 
# MYNS["strength"]
# MYNS["weakness"]
# MYNS["styleofPlay"]
# SCHEMA.startDate SCHEMA.Date
# SCHEMA.endDate   SCHEMA.Date
# SCHEMA.member   SCHEMA.SportsTeam

# %%
SCHEMA.brithPlace
# Out:
# rdflib.term.URIRef('https://schema.org/brithPlace')

# %% [markdown]
# ## DATA

# %%
player_df.columns
# Out:
# Index(['team_history', 'player_url_x', 'name', 'Born', 'Placeofbirth',
#        'Nationality_x', 'Height_x', 'Weight', 'Position(s)', 'Foot',
#        'Current_team_info', 'Homepage', 'sizeofshoe', 'birth_block_x',
#        'player_id_x', 'match_player_id', 'player_url_y', 'Name',
#        'Shirt Number', 'Age', 'Height_y', 'Nationality_y', 'Positions',
#        'Strengths', 'Weaknesses', 'Style_of_Play', 'Current Team', 'DOB',
#        'birth_block_y', 'player_id_y', 'player_id_tot'],
#       dtype='object')

# %%
def nulltoNone(x):
    if x == 'nan':
        return "None"
    else:
        return x

# %%
for idx, row in player_df.iterrows():     
    player_uri = URIRef(MYNS[row["player_id_tot"]])
    my_kg.add((player_uri, RDF.type, SCHEMA.athlete))
    
    ## url
    if row.player_url_x != 'nan':
        my_kg.add((player_uri, MYNS["worldfootball_url"], Literal(row.player_url_x)))
    if row.player_url_y != 'nan':
        my_kg.add((player_uri, MYNS["whoscored_url"], Literal(row.player_url_y)))
    
    ## name
    if row.name != 'nan':
        my_kg.add((player_uri, SCHEMA.name, Literal(row["name"])))
        my_kg.add((player_uri, RDFS.label, Literal(row["name"])))
    else:
        my_kg.add((player_uri, SCHEMA.name, Literal(row["name"])))
        my_kg.add((player_uri, RDFS.label, Literal(row["name"])))
    
    ## birth date
    try:
        tmp = str(int(row.birth_block_x))
        date = date_parse.parse(tmp[:4] + "-" + tmp[4:6] + "-" + tmp[6:])
        my_kg.add((player_uri, SCHEMA.birthDate, Literal(date,datatype=XSD.date)))
    except:
        try:
            tmp = str(int(row.birth_block_y))
            date = date_parse.parse(tmp[:4] + "-" + tmp[4:6] + "-" + tmp[6:])
            my_kg.add((player_uri, SCHEMA.birthDate, Literal(date,datatype=XSD.date)))
        except:
            a = 1
            
            
    ## place of birth
    if row.Placeofbirth != 'nan':
        tmp = ast.literal_eval(row.Placeofbirth)
        for place in tmp:
            my_kg.add((player_uri, SCHEMA.birthPlace, MYNS[re.sub("[^a-zA-Z]", "_", place)]))
            
            
    ## nationality
    if row.Nationality_x != 'nan':
        tmp = ast.literal_eval(row.Nationality_x)
        my_kg.add((player_uri, SCHEMA.nationality, MYNS[re.sub("[^a-zA-Z]", "_", tmp[0])]))
    elif row.Nationality_y != 'nan':
        my_kg.add((player_uri, SCHEMA.nationality, MYNS[re.sub("[^a-zA-Z]", "_", row.Nationality_y)]))
    
    ## Height
    if row.Height_x != 'nan':
        tmp = row.Height_x.split("'")[1][:3]
        my_kg.add((player_uri, SCHEMA.height,Literal(float(tmp),datatype=XSD.float) ))
    elif row.Height_y != 'nan':
        tmp = row.Height_y[:3]
        my_kg.add((player_uri, SCHEMA.height,Literal(float(tmp),datatype=XSD.float) ))
        
    ## Weight
    if row.Weight != 'nan':
        tmp = row.Weight.split("'")[1].split("kg")[0]
        my_kg.add((player_uri, SCHEMA.height,Literal(tmp,datatype=XSD.float) ))
        
    ## Position
    if row["Position(s)"]!= 'nan':
        for pos in row["Position(s)"]:
            pos = re.sub("[^a-zA-Z]", "_", pos)
            my_kg.add((player_uri, MYNS["position"], MYNS[pos] ))
    elif row.Positions!= 'nan':
        for pos in row.Positions:
            pos = re.sub("[^a-zA-Z]", "_", pos)
            my_kg.add((player_uri, MYNS["position"], MYNS[pos] ))
            
    ## Foot
    if row.Foot != 'nan':
        foot = row.Foot.split("'")[1]
        my_kg.add((player_uri, MYNS["Foot"], Literal(foot)))
        
    ## Age
    try:
        a = int(row.Age)
        my_kg.add((player_uri, MYNS["Age"], Literal(row.Age)))
    except:
        a = 1
        
    ## Current Team
    if row.Current_team_info != 'nan':
        js = row.Current_team_info
        js = re.sub("L'A", "LA", js)
        js = re.sub("l'A", "lA", js)
        js = re.sub("O'H", "OH", js)
        js = re.sub("e'e", "ee", js)
        js = re.sub("d'A", "dA", js)
        js = re.sub("a'a", "aa", js)
        js = re.sub("L'H", "LH", js)
        js = re.sub("d'Á", "dÁ", js)
        js = re.sub("'s ", "s ", js)
        js = re.sub('k"s', "ks", js)
        js = re.sub('d\'E', "dE", js)
        current = json.loads(re.sub("'", "\"", js))
        jl = current
        tmp = jl['period'].split(" - ")
        start_month = tmp[0]
        start_month = date_parse.parse(" ".join([start_month.split("/")[1], start_month.split("/")[0], "1"]))
        end_month = tmp[1]
        end_month = date_parse.parse(" ".join([end_month.split("/")[1], end_month.split("/")[0], "1"]))
        team_name =  jl["team_name"]
        position = jl["position"]
        team_url = jl['team_url']
        shirt_number = jl["shirt_Number"]

        revised_name = re.sub("[^a-zA-Z]", "_", team_name)
        current_team = BNode()
        my_kg.add((current_team, MYNS["memberOf"], MYNS[revised_name]))
        my_kg.add((current_team, MYNS["team_name"], Literal(team_name)))
        if position == "Ass. Manager":
            position = "Associate_Manager"
        my_kg.add((current_team, MYNS["position"], MYNS[position]))
        my_kg.add((current_team, MYNS["shirtnumber"], Literal(shirt_number[0][1:])))
        my_kg.add((current_team, MYNS["startAt"], Literal(start_month)))
        my_kg.add((current_team, MYNS["endAt"], Literal(end_month)))
        
        my_kg.add((player_uri, MYNS["Current_Team"], current_team))
        
        
    ## Team history
    team_history = BNode()
    
    if row.team_history != 'nan':
        js = row.team_history
        js = re.sub("L'A", "LA", js)
        js = re.sub("l'A", "lA", js)
        js = re.sub("O'H", "OH", js)
        js = re.sub("e'e", "ee", js)
        js = re.sub("d'A", "dA", js)
        js = re.sub("a'a", "aa", js)
        js = re.sub("L'H", "LH", js)
        js = re.sub("d'Á", "dÁ", js)
        js = re.sub("'s ", "s ", js)
        histories = json.loads(re.sub("'", "\"", js))
        for history in histories:
            team_history_node = BNode()
            jl = histories[history]
            tmp = jl['period'].split(" - ")
            start_month = tmp[0]
            start_month = date_parse.parse(" ".join([start_month.split("/")[1], start_month.split("/")[0], "1"]))
            end_month = tmp[1]
            end_month = date_parse.parse(" ".join([end_month.split("/")[1], end_month.split("/")[0], "1"]))
            team_name =  jl["team"]
            position = jl["position"]
            team_url = jl['team_url']
            
            revised_name = re.sub("[^a-zA-Z]", "_", team_name)
            
            my_kg.add((team_history_node, MYNS["memberOf"], MYNS[revised_name]))
            my_kg.add((team_history_node, MYNS["team_name"], Literal(team_name)))
            if position == "Ass. Manager":
                position = "Associate_Manager"
            my_kg.add((team_history_node, MYNS["position"], MYNS[position]))
            my_kg.add((team_history_node, MYNS["startAt"], Literal(start_month)))
            my_kg.add((team_history_node, MYNS["endAt"], Literal(end_month)))
            my_kg.add((player_uri, MYNS["past_team"], team_history_node))
#     my_kg.add((player_uri, MYNS["Team_History"], team_history))


    ##Strength
    if row.Strengths != 'nan' and row.Strengths != '[]':
        strength = ast.literal_eval(row.Strengths)
        for i in strength:
            node = BNode()
            my_kg.add((player_uri, MYNS["strength"], node))
            my_kg.add((node, MYNS["strength"], Literal(i)))

    ##Weakness
    if row.Weaknesses != 'nan' and row.Weaknesses != '[]':
        weakness = ast.literal_eval(row.Weaknesses)
        for i in weakness:
            node = BNode()
            my_kg.add((player_uri, MYNS["weakness"], node))
            my_kg.add((node, MYNS["weakness"], Literal(i)))
            
    ##player_df["Style_of_Play"]
    if row.Style_of_Play != 'nan' and row.Style_of_Play != '[]':
        Style_of_Play = ast.literal_eval(row.Style_of_Play)
        for i in Style_of_Play:
            node = BNode()
            my_kg.add((player_uri, MYNS["Style_of_Play"], node))
            my_kg.add((node, MYNS["Style_of_Play"], Literal(i)))

# %%
# my_kg.serialize('data.ttl', format="turtle")
# Out:
# <Graph identifier=Ndd76c1df1d4b44e4b54ec48544e9a70e (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# ## Team

# %%
merged_team = pd.read_csv(data_dir + "team_join.csv", index_col = 0)
merged_team
# Out:
#                                         wiki_team_url  \
# 0        https://en.wikipedia.org/wiki/Wigan_Athletic
# 1     https://en.wikipedia.org/wiki/Tottenham_Hotspur
# 2       https://en.wikipedia.org/wiki/Birmingham_City
# 3   https://en.wikipedia.org/wiki/Wolverhampton_Wa...
# 4        https://en.wikipedia.org/wiki/Sunderland_AFC
# 5          https://en.wikipedia.org/wiki/Liverpool_FC
# 6             https://en.wikipedia.org/wiki/Fulham_FC
# 7       https://en.wikipedia.org/wiki/Manchester_City
# 8      https://en.wikipedia.org/wiki/Blackburn_Rovers
# 9           https://en.wikipedia.org/wiki/Aston_Villa
# 10           https://en.wikipedia.org/wiki/Burnley_FC
# 11           https://en.wikipedia.org/wiki/Stoke_City
# 12        https://en.wikipedia.org/wiki/Portsmouth_FC
# 13    https://en.wikipedia.org/wiki/Manchester_United
# 14           https://en.wikipedia.org/wiki/Chelsea_FC
# 15           https://en.wikipedia.org/wiki/Everton_FC
# 16     https://en.wikipedia.org/wiki/Newcastle_United
# 17  https://en.wikipedia.org/wiki/West_Bromwich_Al...
# 18     https://en.wikipedia.org/wiki/Bolton_Wanderers
# 19           https://en.wikipedia.org/wiki/Arsenal_FC
# 20         https://en.wikipedia.org/wiki/Swansea_City
# 21         https://en.wikipedia.org/wiki/Blackpool_FC
# 22            https://en.wikipedia.org/wiki/Hull_City
# 23      https://en.wikipedia.org/wiki/West_Ham_United
# 24  https://en.wikipedia.org/wiki/Queens_Park_Rangers
# 25  https://en.wikipedia.org/wiki/Crystal_Palace_F.C.
# 26       https://en.wikipedia.org/wiki/Southampton_FC
# 27         https://en.wikipedia.org/wiki/Norwich_City
# 28           https://en.wikipedia.org/wiki/Reading_FC
# 29           https://en.wikipedia.org/wiki/Watford_FC
# 30         https://en.wikipedia.org/wiki/Cardiff_City
# 31       https://en.wikipedia.org/wiki/Leicester_City
# 32     https://en.wikipedia.org/wiki/Middlesbrough_FC
# 33      https://en.wikipedia.org/wiki/AFC_Bournemouth
# 34    https://en.wikipedia.org/wiki/Huddersfield_Town
# 36         https://en.wikipedia.org/wiki/Leeds_United
# 37     https://en.wikipedia.org/wiki/Sheffield_United
# 38  https://en.wikipedia.org/wiki/Brighton_&_Hove_...
#
#                      name_x                                 Fullname  \
# 0            Wigan Athletic                WiganAthleticFootballClub
# 1         Tottenham Hotspur             TottenhamHotspurFootballClub
# 2      Birmingham City F.C.               BirminghamCityFootballClub
# 3   Wolverhampton Wanderers       WolverhamptonWanderersFootballClub
# 4         Sunderland A.F.C.        SunderlandAssociationFootballClub
# 5                 Liverpool                    LiverpoolFootballClub
# 6                    Fulham                       FulhamFootballClub
# 7           Manchester City               ManchesterCityFootballClub
# 8          Blackburn Rovers              BlackburnRoversFootballClub
# 9               Aston Villa                   AstonVillaFootballClub
# 10                  Burnley                      BurnleyFootballClub
# 11               Stoke City                    StokeCityFootballClub
# 12          Portsmouth F.C.                   PortsmouthFootballClub
# 13        Manchester United             ManchesterUnitedFootballClub
# 14                  Chelsea                      ChelseaFootballClub
# 15                  Everton                      EvertonFootballClub
# 16    Newcastle United F.C.              NewcastleUnitedFootballClub
# 17     West Bromwich Albion           WestBromwichAlbionFootballClub
# 18         Bolton Wanderers              BoltonWanderersFootballClub
# 19                  Arsenal                   TheArsenalFootballClub
# 20             Swansea City       SwanseaCityAssociationFootballClub
# 21           Blackpool F.C.                    BlackpoolFootballClub
# 22                Hull City          HullCityAssociationFootballClub
# 23     West Ham United F.C.                WestHamUnitedFootballClub
# 24      Queens Park Rangers            QueensParkRangersFootballClub
# 25           Crystal Palace                CrystalPalaceFootballClub
# 26              Southampton                  SouthamptonFootballClub
# 27             Norwich City                  NorwichCityFootballClub
# 28             Reading F.C.                      ReadingFootballClub
# 29                  Watford                      WatfordFootballClub
# 30             Cardiff City                  CardiffCityFootballClub
# 31           Leicester City                LeicesterCityFootballClub
# 32            Middlesbrough                MiddlesbroughFootballClub
# 33          AFC Bournemouth                           AFCBournemouth
# 34        Huddersfield Town  HuddersfieldTownAssociationFootballClub
# 36             Leeds United                  LeedsUnitedFootballClub
# 37    Sheffield United F.C.              SheffieldUnitedFootballClub
# 38   Brighton & Hove Albion          Brighton&HoveAlbionFootballClub
#
#                                           Nickname(s)  \
# 0                            ['TheLatics', 'TheTics']
# 1                                   ['TheLilywhites']
# 2                                           ['Blues']
# 3                              ['WolvesTheWanderers']
# 4                                    ['TheBlackCats']
# 5                                         ['TheReds']
# 6              ['TheCottagersTheWhitesTheLilyWhites']
# 7          ['CityCityzens', 'TheCitizensTheSkyBlues']
# 8    ['Rovers', 'TheBlueandWhites', 'TheRiversiders']
# 9      ['TheVilla', 'TheLions', 'TheClaret&BlueArmy']
# 10                                     ['TheClarets']
# 11                                     ['ThePotters']
# 12                                         ['Pompey']
# 13                                   ['TheRedDevils']
# 14                      ['TheBlues', 'ThePensioners']
# 15  ['TheBlues', 'TheToffees', "ThePeople'sClub", ...
# 16                                     ['TheMagpies']
# 17        ['TheBaggies', 'TheThrostles', 'TheAlbion']
# 18               ['TheTrottersTheWanderersTheWhites']
# 19                       ['TheGunners', 'TheArsenal']
# 20                           ['TheSwans', 'TheJacks']
# 21              ["TheSeasidersThe'PoolTheTangerines"]
# 22                                      ['TheTigers']
# 23  ['TheIronsTheHammersThe', 'Cockney', 'Boys', '...
# 24     ['TheRs', 'Rangers', 'TheHoops', 'Superhoops']
# 25                           ['TheEaglesTheGlaziers']
# 26                                      ['TheSaints']
# 27                      ['TheCanaries', 'TheYellows']
# 28  ['TheRoyals', 'The‘Ding(unofficial)', 'TheBisc...
# 29      ["TheHornetsTheGoldenBoysYellowArmyThe'Orns"]
# 30                                   ['TheBluebirds']
# 31                                       ['TheFoxes']
# 32                                        ['TheBoro']
# 33                            ['TheCherriesBoscombe']
# 34                                    ['TheTerriers']
# 36                           ['TheWhitesThePeacocks']
# 37                                      ['TheBlades']
# 38                          ['TheSeagulls', 'Albion']
#
#                          Founded_x                            Ground  \
# 0                         {'1932'}                     ['DWStadium']
# 1                   {'1882-09-05'}       ['TottenhamHotspurStadium']
# 2                         {'1875'}                    ["StAndrew's"]
# 3                         {'1877'}               ['MolineuxStadium']
# 4                         {'1879'}                ['StadiumofLight']
# 5                   {'1892-06-03'}                       ['Anfield']
# 6                         {'1879'}                 ['CravenCottage']
# 7   {'1880', '1894-04-16', '1887'}       ['CityofManchesterStadium']
# 8                         {'1875'}                     ['EwoodPark']
# 9                   {'1874-11-21'}                     ['VillaPark']
# 10                  {'1882-05-18'}                      ['TurfMoor']
# 11                {'1868', '1863'}                 ['bet365Stadium']
# 12                  {'1898-04-05'}                   ['FrattonPark']
# 13                {'1902', '1878'}                   ['OldTrafford']
# 14                  {'1905-03-10'}                ['StamfordBridge']
# 15                        {'1878'}                  ['GoodisonPark']
# 16                   {'9-12-1892'}                  ["StJames'Park"]
# 17                        {'1878'}                  ['TheHawthorns']
# 18                        {'1874'}     ['UniversityofBoltonStadium']
# 19                           set()               ['EmiratesStadium']
# 20                        {'1912'}            ['Swansea.comStadium']
# 21                  {'1887-07-26'}                ['BloomfieldRoad']
# 22                        {'1904'}                    ['MKMStadium']
# 23    {'1900-07-05', '1895-06-29'}                 ['LondonStadium']
# 24                {'1882', '1886'}  ['KiyanPrinceFoundationStadium']
# 25                  {'1905-09-10'}                  ['SelhurstPark']
# 26                  {'1885-11-21'}               ["StMary'sStadium"]
# 27                  {'1902-06-17'}                    ['CarrowRoad']
# 28                  {'25-12-1871'}       ['SelectCarLeasingStadium']
# 29                        {'1881'}                  ['VicarageRoad']
# 30                        {'1899'}            ['CardiffCityStadium']
# 31                        {'1884'}                               NaN
# 32                   {'18-2-1876'}              ['RiversideStadium']
# 33                        {'1899'}                     ['DeanCourt']
# 34                  {'1908-08-15'}            ["JohnSmith'sStadium"]
# 36                  {'17-10-1919'}                    ['EllandRoad']
# 37                  {'1889-03-22'}                               NaN
# 38                  {'1901-06-24'}                 ['FalmerStadium']
#
#     Capacity                                              Owner  \
# 0      25138                             ['Phoenix2021Limited']
# 1      62850              ['ENICInternationalLtd.', '(85.55%)']
# 2      29409  ['BirminghamSportsHoldings75.00%', 'OrientalRa...
# 3      32050                             ['FosunInternational']
# 4      49000               ['KyrilLouis-Dreyfus', '(majority)']
# 5      53394                              ['FenwaySportsGroup']
# 6      19359                                     ['ShahidKhan']
# 7      53400                              ['CityFootballGroup']
# 8      31367                         ["Venky'sLtd.", '(99.9%)']
# 9      42749                                                NaN
# 10     21944                                                NaN
# 11     30089                                    ['bet365Group']
# 12     20620                             ['TheTornanteCompany']
# 13     74140  ['ManchesterUnitedplc', '(', 'NYSE', '\xa0', '...
# 14     40834                                ['RomanAbramovich']
# 15     39414                                  ['FarhadMoshiri']
# 16     52305  ['PublicInvestmentFund', '(80%)', 'RBSports&Me...
# 17     26688                                    ['LaiGuochuan']
# 18     28723                    ['FootballVentures(Whites)Ltd']
# 19     60704                    ['KroenkeSports&Entertainment']
# 20     21088                                                NaN
# 21     16616                                    ['SimonSadler']
# 22     25586                                     ['AssemAllam']
# 23     60000                                                NaN
# 24     18439  ['TotalSoccerGrowth', '(51%)', 'TuneGroup', '(...
# 25     25486                                                NaN
# 26     32384                                                NaN
# 27     27359                ['DeliaSmith', 'MichaelWynn-Jones']
# 28     24161             ['DaiYongge', 'andDaiXiuli(majority)']
# 29     22200                                      ['GinoPozzo']
# 30     33316                                     ['VincentTan']
# 31     32261                                      ['KingPower']
# 32     34742                                    ['SteveGibson']
# 33     11364                                     ['MaximDemin']
# 34     24121                                                NaN
# 36     37792  ['AserGroupHolding', '(56%)', '49ersEnterprise...
# 37     32050                                ['SheffieldUnited']
# 38     31800                                                NaN
#
#                      Chairman                          Manager  ...  \
# 0               TalalAlHammad               ['LeamRichardson']  ...
# 1                  DanielLevy                              NaN  ...
# 2                         NaN                              NaN  ...
# 3                     JeffShi                              NaN  ...
# 4          KyrilLouis-Dreyfus                              NaN  ...
# 5                   TomWerner                  ['JürgenKlopp']  ...
# 6                  ShahidKhan                              NaN  ...
# 7           KhaldoonAlMubarak                 ['PepGuardiola']  ...
# 8                         NaN                  ['TonyMowbray']  ...
# 9               NassefSawiris                              NaN  ...
# 10                   AlanPace                    ['SeanDyche']  ...
# 11                        NaN               ["MichaelO'Neill"]  ...
# 12              MichaelEisner                  ['DannyCowley']  ...
# 13                        NaN  ['MichaelCarrick', '(interim)']  ...
# 14                  BruceBuck                              NaN  ...
# 15              BillKenwright                ['RafaelBenítez']  ...
# 16           YasirAl-Rumayyan                    ['EddieHowe']  ...
# 17                    LiPiyue                              NaN  ...
# 18              SharonBrittan                     ['IanEvatt']  ...
# 19                        NaN                  ['MikelArteta']  ...
# 20               JulianWinter                              NaN  ...
# 21                        NaN                              NaN  ...
# 22                 AssemAllam                  ['GrantMcCann']  ...
# 23                        NaN                   ['DavidMoyes']  ...
# 24                 AmitBhatia                ['MarkWarburton']  ...
# 25                SteveParish                ['PatrickVieira']  ...
# 26                 GaoJisheng              ['RalphHasenhüttl']  ...
# 27                        NaN                              NaN  ...
# 28                        NaN               ['VeljkoPaunović']  ...
# 29               ScottDuxbury                              NaN  ...
# 30               MehmetDalman                 ['SteveMorison']  ...
# 31  AiyawattSrivaddhanaprabha               ['BrendanRodgers']  ...
# 32                SteveGibson                  ['ChrisWilder']  ...
# 33                 JeffMostyn                              NaN  ...
# 34             PhilHodgkinson                              NaN  ...
# 36           AndreaRadrizzani                              NaN  ...
# 37  YusufGiansiracusa(acting)             ['SlavišaJokanović']  ...
# 38                  TonyBloom                              NaN  ...
#
#              Opened  id                   name_y  \
# 0               NaN   0           Wigan Athletic
# 1               NaN   1        Tottenham Hotspur
# 2               NaN   2          Birmingham City
# 3               NaN   3  Wolverhampton Wanderers
# 4               NaN   4           Sunderland AFC
# 5               NaN   5             Liverpool FC
# 6               NaN   6                Fulham FC
# 7               NaN   7          Manchester City
# 8               NaN   8         Blackburn Rovers
# 9               NaN   9              Aston Villa
# 10              NaN  10               Burnley FC
# 11              NaN  11               Stoke City
# 12              NaN  12            Portsmouth FC
# 13              NaN  13        Manchester United
# 14              NaN  14               Chelsea FC
# 15              NaN  15               Everton FC
# 16              NaN  16         Newcastle United
# 17              NaN  17     West Bromwich Albion
# 18              NaN  18         Bolton Wanderers
# 19              NaN  19               Arsenal FC
# 20              NaN  20             Swansea City
# 21              NaN  21             Blackpool FC
# 22              NaN  22                Hull City
# 23              NaN  23          West Ham United
# 24              NaN  24      Queens Park Rangers
# 25              NaN  25           Crystal Palace
# 26              NaN  26           Southampton FC
# 27              NaN  27             Norwich City
# 28              NaN  28               Reading FC
# 29              NaN  29               Watford FC
# 30              NaN  30             Cardiff City
# 31              NaN  31           Leicester City
# 32              NaN  32         Middlesbrough FC
# 33              NaN  33          AFC Bournemouth
# 34              NaN  34        Huddersfield Town
# 36              NaN  35             Leeds United
# 37  ['30April1855']  36         Sheffield United
# 38              NaN  37   Brighton & Hove Albion
#
#                                        world_team_url      Country  \
# 0   https://www.worldfootball.net/teams/wigan-athl...  ['England']
# 1   https://www.worldfootball.net/teams/tottenham-...  ['England']
# 2   https://www.worldfootball.net/teams/birmingham...  ['England']
# 3   https://www.worldfootball.net/teams/wolverhamp...  ['England']
# 4   https://www.worldfootball.net/teams/sunderland...  ['England']
# 5   https://www.worldfootball.net/teams/liverpool-fc/  ['England']
# 6      https://www.worldfootball.net/teams/fulham-fc/  ['England']
# 7   https://www.worldfootball.net/teams/manchester...  ['England']
# 8   https://www.worldfootball.net/teams/blackburn-...  ['England']
# 9    https://www.worldfootball.net/teams/aston-villa/  ['England']
# 10    https://www.worldfootball.net/teams/burnley-fc/  ['England']
# 11    https://www.worldfootball.net/teams/stoke-city/  ['England']
# 12  https://www.worldfootball.net/teams/portsmouth...  ['England']
# 13  https://www.worldfootball.net/teams/manchester...  ['England']
# 14    https://www.worldfootball.net/teams/chelsea-fc/  ['England']
# 15    https://www.worldfootball.net/teams/everton-fc/  ['England']
# 16  https://www.worldfootball.net/teams/newcastle-...  ['England']
# 17  https://www.worldfootball.net/teams/west-bromw...  ['England']
# 18  https://www.worldfootball.net/teams/bolton-wan...  ['England']
# 19    https://www.worldfootball.net/teams/arsenal-fc/  ['England']
# 20  https://www.worldfootball.net/teams/swansea-city/    ['Wales']
# 21  https://www.worldfootball.net/teams/blackpool-fc/  ['England']
# 22     https://www.worldfootball.net/teams/hull-city/  ['England']
# 23  https://www.worldfootball.net/teams/west-ham-u...  ['England']
# 24  https://www.worldfootball.net/teams/queens-par...  ['England']
# 25  https://www.worldfootball.net/teams/crystal-pa...  ['England']
# 26  https://www.worldfootball.net/teams/southampto...  ['England']
# 27  https://www.worldfootball.net/teams/norwich-city/  ['England']
# 28    https://www.worldfootball.net/teams/reading-fc/  ['England']
# 29    https://www.worldfootball.net/teams/watford-fc/  ['England']
# 30  https://www.worldfootball.net/teams/cardiff-city/    ['Wales']
# 31  https://www.worldfootball.net/teams/leicester-...  ['England']
# 32  https://www.worldfootball.net/teams/middlesbro...  ['England']
# 33  https://www.worldfootball.net/teams/afc-bourne...  ['England']
# 34  https://www.worldfootball.net/teams/huddersfie...  ['England']
# 36  https://www.worldfootball.net/teams/leeds-united/  ['England']
# 37  https://www.worldfootball.net/teams/sheffield-...  ['England']
# 38  https://www.worldfootball.net/teams/brighton-h...  ['England']
#
#          Founded_y                            stadium  \
# 0   ['01/01/1932']                      ['DWStadium']
# 1   ['05/09/1882']        ['TottenhamHotspurStadium']
# 2   ['01/01/1875']               ["StAndrew'sGround"]
# 3   ['01/01/1877']                ['MolineuxStadium']
# 4   ['01/01/1879']                 ['StadiumofLight']
# 5   ['15/03/1892']                        ['Anfield']
# 6   ['01/01/1879']                  ['CravenCottage']
# 7   ['01/01/1880']                  ['EtihadStadium']
# 8   ['05/11/1875']                      ['EwoodPark']
# 9      ['03/1874']                      ['VillaPark']
# 10  ['01/01/1882']                       ['TurfMoor']
# 11  ['01/01/1863']                  ['bet365Stadium']
# 12  ['05/04/1898']                    ['FrattonPark']
# 13  ['01/03/1878']                    ['OldTrafford']
# 14  ['14/03/1905']                 ['StamfordBridge']
# 15        ['1878']                   ['GoodisonPark']
# 16  ['01/01/1882']                   ["StJames'Park"]
# 17  ['01/01/1878']                   ['TheHawthorns']
# 18  ['01/01/1874']      ['UniversityofBoltonStadium']
# 19  ['01/10/1886']                ['EmiratesStadium']
# 20        ['1912']                 ['LibertyStadium']
# 21  ['26/07/1887']                 ['BloomfieldRoad']
# 22  ['01/01/1904']  ['KingstonCommunicationsStadium']
# 23  ['01/01/1895']                  ['LondonStadium']
# 24  ['01/01/1882']                     ['LoftusRoad']
# 25  ['01/01/1905']                   ['SelhurstPark']
# 26  ['01/01/1885']                    ["SaintMary's"]
# 27  ['17/06/1902']                     ['CarrowRoad']
# 28        ['1871']        ['SelectCarLeasingStadium']
# 29        ['1881']                   ['VicarageRoad']
# 30        ['1899']             ['CardiffCityStadium']
# 31  ['01/01/1884']               ['KingPowerStadium']
# 32        ['1876']                      ['Riverside']
# 33  ['01/01/1899']                ['VitalityStadium']
# 34  ['01/01/1908']             ['JohnSmith’sStadium']
# 36  ['17/10/1919']                     ['EllandRoad']
# 37  ['01/01/1889']                    ['BramallLane']
# 38  ['24/06/1901']                    ['AmexStadium']
#
#                                      Homepage                     name  \
# 0           ['https//www.wiganathletic.com/']                    Wigan
# 1                         ['www.spurs.co.uk']                Tottenham
# 2                            ['www.bcfc.com']               Birmingham
# 3                ['https//www.wolves.co.uk/']  Wolverhampton Wanderers
# 4                            ['www.safc.com']               Sunderland
# 5                    ['www.liverpoolfc.com/']                Liverpool
# 6                        ['www.fulhamfc.com']                   Fulham
# 7                 ['https//www.mancity.com/']          Manchester City
# 8                ['https//www.rovers.co.uk/']                Blackburn
# 9                          ['www.avfc.co.uk']              Aston Villa
# 10    ['https//www.burnleyfootballclub.com/']                  Burnley
# 11            ['https//www.stokecityfc.com/']                    Stoke
# 12                 ['www.portsmouthfc.co.uk']               Portsmouth
# 13                        ['www.manutd.com/']        Manchester United
# 14              ['https//www.chelseafc.com/']                  Chelsea
# 15                      ['www.evertonfc.com']                  Everton
# 16                 ['https//www.nufc.co.uk/']         Newcastle United
# 17                  ['https//www.wba.co.uk/']     West Bromwich Albion
# 18                 ['https//www.bwfc.co.uk/']                   Bolton
# 19                ['https//www.arsenal.com/']                  Arsenal
# 20            ['https//www.swanseacity.com/']                  Swansea
# 21                  ['www.blackpoolfc.co.uk']                Blackpool
# 22         ['https//www.hullcitytigers.com/']                     Hull
# 23                  ['https//www.whufc.com/']                 West Ham
# 24                          ['www.qpr.co.uk']      Queens Park Rangers
# 25                 ['https//www.cpfc.co.uk/']           Crystal Palace
# 26              ['https//southamptonfc.com/']              Southampton
# 27                     ['www.canaries.co.uk']                  Norwich
# 28                    ['www.readingfc.co.uk']                  Reading
# 29              ['https//www.watfordfc.com/']                  Watford
# 30                ['www.cardiffcityfc.co.uk']                  Cardiff
# 31                   ['https//www.lcfc.com/']                Leicester
# 32                          ['www.mfc.co.uk']            Middlesbrough
# 33                 ['https//www.afcb.co.uk/']              Bournemouth
# 34                  ['https//www.htafc.com/']             Huddersfield
# 36                    ['www.leedsunited.com']                    Leeds
# 37                         ['www.sufc.co.uk']         Sheffield United
# 38  ['https//www.brightonandhovealbion.com/']                 Brighton
#
#                                          who_team_url
# 0   https://www.whoscored.com/Teams/194/Show/Engla...
# 1   https://www.whoscored.com/Teams/30/Show/Englan...
# 2   https://www.whoscored.com/Teams/157/Show/Engla...
# 3   https://www.whoscored.com/Teams/161/Show/Engla...
# 4   https://www.whoscored.com/Teams/16/Show/Englan...
# 5   https://www.whoscored.com/Teams/26/Show/Englan...
# 6   https://www.whoscored.com/Teams/170/Show/Engla...
# 7   https://www.whoscored.com/Teams/167/Show/Engla...
# 8   https://www.whoscored.com/Teams/158/Show/Engla...
# 9   https://www.whoscored.com/Teams/24/Show/Englan...
# 10  https://www.whoscored.com/Teams/184/Show/Engla...
# 11  https://www.whoscored.com/Teams/96/Show/Englan...
# 12  https://www.whoscored.com/Teams/169/Show/Engla...
# 13  https://www.whoscored.com/Teams/32/Show/Englan...
# 14  https://www.whoscored.com/Teams/15/Show/Englan...
# 15  https://www.whoscored.com/Teams/31/Show/Englan...
# 16  https://www.whoscored.com/Teams/23/Show/Englan...
# 17  https://www.whoscored.com/Teams/175/Show/Engla...
# 18  https://www.whoscored.com/Teams/92/Show/Englan...
# 19  https://www.whoscored.com/Teams/13/Show/Englan...
# 20  https://www.whoscored.com/Teams/259/Show/Wales...
# 21  https://www.whoscored.com/Teams/93/Show/Englan...
# 22  https://www.whoscored.com/Teams/214/Show/Engla...
# 23  https://www.whoscored.com/Teams/29/Show/Englan...
# 24  https://www.whoscored.com/Teams/171/Show/Engla...
# 25  https://www.whoscored.com/Teams/162/Show/Engla...
# 26  https://www.whoscored.com/Teams/18/Show/Englan...
# 27  https://www.whoscored.com/Teams/168/Show/Engla...
# 28  https://www.whoscored.com/Teams/94/Show/Englan...
# 29  https://www.whoscored.com/Teams/27/Show/Englan...
# 30  https://www.whoscored.com/Teams/188/Show/Wales...
# 31  https://www.whoscored.com/Teams/14/Show/Englan...
# 32  https://www.whoscored.com/Teams/21/Show/Englan...
# 33  https://www.whoscored.com/Teams/183/Show/Engla...
# 34  https://www.whoscored.com/Teams/166/Show/Engla...
# 36  https://www.whoscored.com/Teams/19/Show/Englan...
# 37  https://www.whoscored.com/Teams/163/Show/Engla...
# 38  https://www.whoscored.com/Teams/211/Show/Engla...
#
# [38 rows x 40 columns]

# %%
team_url_list = []
for i, j in team_list:
    team_url_list.append(j)

target_name_list = []
for idx, row in merged_team.iterrows():
    for name, url in set(team_list):
        if url == row.world_team_url:
            revised_name = re.sub("[^a-zA-Z]", "_", name)
            target_name_list.append(revised_name) 
merged_team["myns_name"] = target_name_list

# %%
merged_team = merged_team.fillna("nan")

# %%
merged_team.columns
# Out:
# Index(['wiki_team_url', 'name_x', 'Fullname', 'Nickname(s)', 'Founded_x',
#        'Ground', 'Capacity', 'Owner', 'Chairman', 'Manager', 'League',
#        '2020–21', 'Website', 'Homecolours', 'Headcoach', 'Shortname',
#        'Coordinates', 'Architect', 'Expanded', 'Maincontractors', 'Renovated',
#        'HeadCoach', 'CEO', 'Owner(s)', 'Joint-Chairman', 'Co-chairmen',
#        'Owners', 'Stadium', 'Anear-fullcapacity', 'Location', 'Opened', 'id',
#        'name_y', 'world_team_url', 'Country', 'Founded_y', 'stadium',
#        'Homepage', 'name', 'who_team_url', 'myns_name'],
#       dtype='object')

# %% [markdown]
# ### League

# %%
#League list
league_list = [ast.literal_eval(i)[0] for i in set(merged_team["League"])]

# %%
league_list
# Out:
# ['PremierLeague', 'EFLChampionship', 'LeagueOne', 'EFLLeagueOne']

# %%
for league in league_list:
    league_uri = URIRef(MYNS[league])
    my_kg.add((league_uri, RDF.type, MYNS["League"]))
    my_kg.add((league_uri, RDFS.label, Literal(league)))

# %%
merged_team.columns
# Out:
# Index(['wiki_team_url', 'name_x', 'Fullname', 'Nickname(s)', 'Founded_x',
#        'Ground', 'Capacity', 'Owner', 'Chairman', 'Manager', 'League',
#        '2020–21', 'Website', 'Homecolours', 'Headcoach', 'Shortname',
#        'Coordinates', 'Architect', 'Expanded', 'Maincontractors', 'Renovated',
#        'HeadCoach', 'CEO', 'Owner(s)', 'Joint-Chairman', 'Co-chairmen',
#        'Owners', 'Stadium', 'Anear-fullcapacity', 'Location', 'Opened', 'id',
#        'name_y', 'world_team_url', 'Country', 'Founded_y', 'stadium',
#        'Homepage', 'name', 'who_team_url', 'myns_name'],
#       dtype='object')

# %% [markdown]
# ### Stadium

# %%
stadium_list = list(merged_team.stadium.apply(lambda x : re.sub(r"(\w)([A-Z])", r"\1 \2",x[2:-2])))

# %%
for cap, stadium in zip(list(merged_team.Capacity), stadium_list):
    stadium_name = re.sub("[^a-zA-Z]", "_", stadium)
    stadium_uri = URIRef(MYNS[stadium_name])
    my_kg.add((stadium_uri, RDF.type, MYNS["Stadium"]))
    my_kg.add((stadium_uri, RDFS.label, Literal(stadium)))
    my_kg.add((stadium_uri, MYNS["capacity"], Literal(int(cap))))

# %% [markdown]
# ## Team Info

# %%
for idx, row in merged_team.iterrows():
    team_uri = MYNS[row.myns_name]
    ## url
    if row.world_team_url != 'nan':
        my_kg.add((team_uri, MYNS["worldfootball_url"], Literal(row.world_team_url)))
    if row.who_team_url != 'nan':
        my_kg.add((team_uri, MYNS["whoscored_url"], Literal(row.who_team_url)))
    if row.wiki_team_url != 'nan':
        my_kg.add((team_uri, MYNS["wikipedia_url"], Literal(row.wiki_team_url)))        
        
    ##team_name
    my_kg.add((team_uri, MYNS["name"], Literal(row.name_x)))
    
    ##Founded
    tmp = row.Founded_y.split("'")[1].split('/')
    if len(tmp) == 3:
        tmp = date_parse.parse(" ".join([tmp[2], tmp[1], tmp[0]]))
    elif len(tmp) == 2:
        tmp = date_parse.parse(" ".join([tmp[1], tmp[0]]))
    elif len(tmp) == 1:
        tmp = date_parse.parse(" ".join([tmp[0]]))
    my_kg.add((team_uri, MYNS['FoundedAt'], Literal(tmp)))
    
    ##Chairman
    if row.Chairman != 'nan':
        tmp = re.sub(r"(\w)([A-Z])", r"\1 \2",row.Chairman)
        my_kg.add((team_uri, MYNS['Chairman'], Literal(tmp)))
        
    ##Owner
    if row.Owner != 'nan':
        tmp = ast.literal_eval(row.Owner)[0]
        tmp = re.sub(r"(\w)([A-Z])", r"\1 \2", tmp)
        my_kg.add((team_uri, MYNS['owner'], Literal(tmp)))
        
    ##League
    if row.League != 'nan':
        league = ast.literal_eval(row.League)[0]
        my_kg.add((team_uri, MYNS["league"], MYNS[league]))
        
    ##Website
    if row.Homepage != 'nan':
        my_kg.add((team_uri, MYNS["Website"], Literal(row.Homepage[2:-2])))
    
    ##Stadium
    if row.stadium != 'nan':
        my_kg.add((team_uri, MYNS["mainStadium"], MYNS[re.sub("[^a-zA-Z]", "_", stadium)]))

# %%
# my_kg.serialize(data_dir + 'data.ttl', format="turtle")

# %% [markdown]
# ## Game

# %%
game_merged = pd.read_csv(data_dir + "game_join.csv")

# %% [markdown]
# ### Season

# %%
season_list = game_merged["season_world"].drop_duplicates().dropna()

# %%
for season in season_list:
    season_name = re.sub("[^a-zA-Z0-9]", "_", season)
    season_uri = URIRef(MYNS[season_name])
    my_kg.add((season_uri, RDF.type, MYNS["season"]))
    my_kg.add((season_uri, RDFS.label, Literal(season_name)))

# %%
game_merged.isna().sum()
# Out:
# season_world        347
# round               347
# data                347
# time_world          347
# home_team_world     347
#                    ...
# BSD                3259
# BSA                3259
# SBH                3652
# SBD                3652
# SBA                3652
# Length: 116, dtype: int64

# %%
def f(x):
    return str(x.home_team_id) + "__" + str(x.away_team_id) +"__" + re.sub("-","_",x.date)
game_merged["identifier"] = game_merged.apply(f, axis = 1)

# %%
def f(x):
    if x!="nan":
        return x.split("/")[4]
player_df["who_id"] = player_df["player_url_y"].apply(f)

# %%
merged_team2 = pd.read_csv(data_dir + "team_match.csv", index_col = 0)

merged_team2.reset_index(inplace = True)

team_url_list = []
for i, j in team_list:
    team_url_list.append(j)

target_name_list = []
for idx, row in merged_team2.iterrows():
    for name, url in set(team_list):
        if url == row.world_team_url:
            revised_name = re.sub("[^a-zA-Z]", "_", name)
            target_name_list.append(revised_name) 
merged_team2["myns_name"] = target_name_list

# %%
merged_team = merged_team.merge(merged_team2, left_on = ['wiki_team_url','world_team_url','who_team_url', 'id', 'myns_name'], right_on = ['wiki_team_url','world_team_url','who_team_url', 'id', 'myns_name'], how = 'outer')

# %%
merged_team.loc[38,'name'] = 'brentford'
merged_team.loc[38,'name_x'] = 'brentford'

# %%
## structured team name

Lev = NormalizedLevenshtein().similarity

structured_name = []
for idx, row in merged_team.iterrows():
    sim = 0
    str_name = 0
    for name in list(game_merged["HomeTeam"].dropna().drop_duplicates()):
        if Lev(row.name_x, name)>sim:
            sim = Lev(row.name_x, name)
            str_name = name
    
    structured_name.append(str_name)

# %%
merged_team['structured_name'] = structured_name

# %%
merged_team.loc[36, 'structured_name'] = 'nan'
merged_team.loc[35, 'structured_name'] = 'nan'
merged_team.loc[24, 'structured_name'] = 'QPR'
merged_team.loc[22, 'structured_name'] = 'Hull'
merged_team.loc[20, 'structured_name'] = 'Swansea'
merged_team.loc[11, 'structured_name'] = 'Stoke'
merged_team.loc[3, 'structured_name'] = 'Wolves'

# %%
game = game_merged.fillna("nan")
for idx, row in tqdm(game.iterrows()):
    game_uri = URIRef(MYNS[row["identifier"]])
    my_kg.add((game_uri, RDF.type, MYNS["event"]))
    
    ## season
    if row.season_world != "nan":
        my_kg.add((game_uri, MYNS["seasonOf"], MYNS[re.sub("[^a-zA-Z0-9]", "_", row.season_world)]))
    elif row.season_who != "nan":
        my_kg.add((game_uri, MYNS["seasonOf"], MYNS[re.sub("[^a-zA-Z0-9]", "_", row.season_who)]))
        
    ## round
    if row['round'] != "nan":
        my_kg.add((game_uri, MYNS["roundOf"], Literal(int(row["round"]))))
    
    ## score
    if row["score"] != "nan":
        my_kg.add((game_uri, MYNS["scoreOf"], Literal(row["score"])))
    elif row["FTHG"] != "nan":
        score = str(row.FTHG) + ":" + str(row.FTAG)
        my_kg.add((game_uri, MYNS["scoreOf"], Literal(score)))
        
    ##date
    if row["time_world"] != "nan":
        if row["date"] != "nan":
            my_kg.add((game_uri, MYNS["DateTime"], Literal(date_parse.parse(row.date + " " + row.time_world))))
    elif row["time_who"] != "nan":
        if row["date"] != "nan":
            my_kg.add((game_uri, MYNS["DateTime"], Literal(date_parse.parse(row.date + " " + row.time_who))))
    elif row["date"] != "nan":
        my_kg.add((game_uri, MYNS["DateTime"], Literal(date_parse.parse(row.date))))   
        
    ##home_team
    if row["home_team_url_who"] != 'nan':
        home_team_id_who =row.home_team_url_who.split("/")[4]
        home_team_name = merged_team[merged_team['who_team_url'].apply(lambda x : x.split("/")[4]) == home_team_id_who]['myns_name'].values[0]
        my_kg.add((game_uri, MYNS["awayTeam"], MYNS[home_team_name]))
    elif row['home_team_url_world'] != 'nan':
        home_team_name = merged_team[merged_team['world_team_url'] == row["home_team_url_world"]]['myns_name'].values[0]
        my_kg.add((game_uri, MYNS["homeTeam"], MYNS[home_team_name])) 
    elif row["HomeTeam"] != 'nan':
        home_team_name = merged_team[merged_team['structured_name'] == row["HomeTeam"]]['myns_name'].values[0]
        my_kg.add((game_uri, MYNS["homeTeam"], MYNS[home_team_name])) 
     
    if row["away_team_url_who"] != 'nan':
        away_team_id_who =row.away_team_url_who.split("/")[4]
        away_team_name = merged_team[merged_team['who_team_url'].apply(lambda x : x.split("/")[4]) == away_team_id_who]['myns_name'].values[0]
        my_kg.add((game_uri, MYNS["awayTeam"], MYNS[away_team_name]))
    elif row['away_team_url_world'] != 'nan':
        away_team_name = merged_team[merged_team['world_team_url'] == row["away_team_url_world"]]['myns_name'].values[0]
        my_kg.add((game_uri, MYNS["awayTeam"], MYNS[away_team_name])) 
    elif row["AwayTeam"] != 'nan':
        away_team_name = merged_team[merged_team['structured_name'] == row["AwayTeam"]]['myns_name'].values[0]
        my_kg.add((game_uri, MYNS["awayTeam"], MYNS[away_team_name]))
        
        
    if row.home_team_players != "nan":   
        tmp = json.loads(re.sub(r"(\w)\"(\w)", r"\1-\2",re.sub("'", "\"",row.home_team_players)))
#         tmp = json.loads(re.sub(r"(\w)\"(\w)", r"\1-\2",re.sub("'", "\"",row.home_team_players)))
        home_url_list = []
        for i in tmp:
            home_url_list.append(i["player_url"])
            
    if row.away_team_players != "nan":   
        tmp = json.loads(re.sub(r"(\w)\"(\w)", r"\1-\2",re.sub("'", "\"",row.away_team_players)))
        away_url_list = []
        for i in tmp:
            away_url_list.append(i["player_url"])
     
    goal_player_id_list = []
    if row.goal_player_url != "nan" and row.home_team_players != '[]':
        for url in ast.literal_eval(row.goal_player_url):
            try:
                goal_player_id = player_df[player_df["player_url_x"] == url]["player_id_tot"].values[0]
                goal_player_id_list.append(goal_player_id)
            except:
                continue
    goal_counter = Counter(goal_player_id_list)           
            
     
    ## Player rating
    if row["player_rating"] != "nan":
        rating_dict = ast.literal_eval(row["player_rating"])
        for player_key in rating_dict:
            stmt = BNode()
            try:
                player_id = player_df[player_df["who_id"] == player_key].fillna("nan")["player_id_tot"].values[0]
            except:
                continue
            rating = rating_dict[player_key]["rating"]
            shirt_number = rating_dict[player_key]["shirt_number"].split(".")[0]

            my_kg.add((MYNS[player_id], MYNS["participate_in"], stmt))
            if player_id in goal_player_id_list:
                my_kg.add((stmt, MYNS["goal_assist"], Literal(int(goal_counter[player_id]), datatype=XSD.integer)))
            my_kg.add((stmt, MYNS["participate_in"], game_uri))
            my_kg.add((stmt, MYNS["rating"], Literal(rating)))
            my_kg.add((stmt, MYNS["shirt_number"], Literal(shirt_number)))
            
            try:
                player_url = player_df[player_df["who_id"] == player_key].fillna("nan")["player_url_x"].values[0]
            except:
                continue
                
            if player_url in home_url_list:
                my_kg.add((stmt, MYNS["teamAgainst"], MYNS[away_team_name]))
            if player_url in away_url_list:
                my_kg.add((stmt, MYNS["teamAgainst"], MYNS[home_team_name]))
# Out:
# 4838it [10:48,  7.46it/s]

# %%
my_kg.serialize(data_dir + 'data.ttl', format="turtle")
# Out:
# <Graph identifier=Ndd76c1df1d4b44e4b54ec48544e9a70e (<class 'rdflib.graph.Graph'>)>
